# %%
#import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
#read the file 
ipd_under_5  = pd.read_csv('IPD-Under-5-years-2012.csv')

# %%
# the shape of the data
ipd_under_5.shape
# Out:
# (21, 44)

# %% [markdown]
# 21 rows and 44 colums

# %%
#check the columns name
ipd_under_5.columns
# Out:
# Index([u'Region', u'Acute Respiratory Infections', u'Diarrhoeal Diseases',
#        u'Intestinal Worms', u'Malaria- Severe, Complicated',
#        u'Malaria- Uncomplicated', u'Schistosomiasis', u'Tuberculosis',
#        u'Severe Protein Ernegy Malnut.',
#        u'Other Nutritional Disorders (toa PEM)', u'Sickle  cell Disease',
#        u'Anaemia', u'Epilepsy', u'Ear Infections', u'Eye Infections',
#        u'Other Eye Diseases', u'Vitamin A Defc/Xerophthalmia',
#        u'Cardiac Failure', u'Other Cardiovascular', u'Rheumatic Fever',
#        u'Bronchial Asthma', u'Pneumonia', u'Respiratory Disease (Nyinginezo)',
#        u'Non-Inf. Gastrointestinal Diseases (Others)',
#        u'Urinary tract Infections (UTI)', u'Non-Inf. Kidney Diseases',
#        u'Skin Infections', u'Skin Diseases Non-Infectious', u'Joint Disorders',
#        u'Peri-natal and Neonata Conditions', u'Snake and Insect Bites',
#        u'Burns', u'Poisoning', u'HIV/AIDS', u'Neoplasms',
# ...

# %%
#look at the train set
ipd_under_5.head()
# Out:
#           Region  Acute Respiratory Infections  Diarrhoeal Diseases  \
# 0         Arusha                          1952                 2241
# 1  Dar es Salaam                          1126                 7452
# 2         Dodoma                          1068                 1697
# 3         Iringa                          1599                 2562
# 4         Kagera                          3763                 4181
#
#    Intestinal Worms  Malaria- Severe, Complicated  Malaria- Uncomplicated  \
# 0                44                          2466                  4204.0
# 1                 3                         23278                     NaN
# 2                56                          6735                  1482.0
# 3               155                          2295                  4561.0
# 4               851                         20412                  7633.0
#
#    Schistosomiasis  Tuberculosis  Severe Protein Ernegy Malnut.  \
# ...

# %%
#check the missing values
ipd_under_5.isnull().any()
# Out:
# Region                                         False
# Acute Respiratory Infections                   False
# Diarrhoeal Diseases                            False
# Intestinal Worms                               False
# Malaria- Severe, Complicated                   False
# Malaria- Uncomplicated                          True
# Schistosomiasis                                False
# Tuberculosis                                   False
# Severe Protein Ernegy Malnut.                  False
# Other Nutritional Disorders (toa PEM)          False
# Sickle  cell Disease                           False
# Anaemia                                        False
# Epilepsy                                       False
# Ear Infections                                 False
# Eye Infections                                 False
# Other Eye Diseases                             False
# Vitamin A Defc/Xerophthalmia                   False
# Cardiac Failure                                False
# ...

# %% [markdown]
# Column of Malaria- Uncomplicated contains missing values

# %% [markdown]
# # Descriptive Statistic

# %%
#summary statistics of numerical columns
ipd_under_5.describe()
# Out:
#        Acute Respiratory Infections  Diarrhoeal Diseases  Intestinal Worms  \
# count                     21.000000            21.000000         21.000000
# mean                    1920.428571          2626.619048        182.380952
# std                     3199.365555          1626.566367        273.512244
# min                      301.000000           406.000000          0.000000
# 25%                      696.000000          1697.000000         18.000000
# 50%                     1068.000000          2204.000000         60.000000
# 75%                     1806.000000          3180.000000        185.000000
# max                    15435.000000          7452.000000        950.000000
#
#        Malaria- Severe, Complicated  Malaria- Uncomplicated  Schistosomiasis  \
# count                     21.000000                20.00000        21.000000
# mean                    9263.571429              5942.25000        57.809524
# ...

# %%
#check total number of Poeple in each Region who were affected
ipd_under_5[['Region','Total']]
# Out:
#            Region  Total
# 0          Arusha  27370
# 1   Dar es Salaam  66095
# 2          Dodoma  18322
# 3          Iringa  22880
# 4          Kagera  52077
# 5          Kigoma  17809
# 6     Kilimanjaro  40889
# 7           Lindi   9778
# 8            Mara  54145
# 9         Manyara  24089
# 10          Mbeya  32201
# 11       Morogoro    336
# 12         Mtwara  15321
# 13         Mwanza  51974
# 14          Pwani   9843
# 15          Rukwa  14117
# 16         Ruvuma  59942
# 17        Singida  39454
# 18      Shinyanga  72374
# 19         Tabora  36755
# 20          Tanga  30126

# %%
ipd_under_5['Total'].max()
# Out:
# 72374

# %% [markdown]
# Most people from Shinyanga were affected by these kinds of Diseases

# %%
ipd_under_5['Total'].min()
# Out:
# 336

# %% [markdown]
# Few people from Morogoro were affected by these kinds of Diseases

# %%
# Bar Diagram of Region vs Total
ipd_under_5[['Region','Total']].plot.bar()

# %% [markdown]
# It is clear that Citizen of Shinyanga were most affected by different diseases(index number 18)
